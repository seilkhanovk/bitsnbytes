# %%
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv('C:/Users/Rakhman/Anaconda3/dataBLE/soc.csv')
df
# Out:
#            user_id  age     sex married  friends  subscriptions  photos  \
# 0       b.bimbetov   18    male     yes      249             24      14
# 1       allbackoff   18    male      no      201              9       2
# 2  prokrasteenator   18    male      no      187             59      19
# 3          yasmink   18  female      no      321             38       2
# 4      birzhanpvvm   25    male      no     7308            803     192
#
#    gifts  last_visit  followers  followings  posts  avg_likes  avg_comments  \
# 0     93           0        598         431     10        314            14
# 1      0           2        601         547     28        197             3
# 2    152           0        432         354      9        112             6
# 3      0           0        344         415     69         60             1
# 4      0           0     866279         270    470      69188          1403
#
#    avg_views  target
# 0        503       1
# 1        488       1
# 2        345       1
# 3        230       1
# 4     321260       1

# %%
def age_classifier(x):
    if x<18:
        return 0
    if x<25: 
        return 10
    if x<40:
        return 20
    if x<63:
        return 15
    return 5

def sex_classifier(x):
    return 1

def married_classifier(x):
    if x=='yes':
        return 10
    return 20

def friends_classifier(x):
    if x>500:
        return 25
    if x>200:
        return 15
    if x>100:
        return 10
    if x>20:
        return 5
    return 0

def subscriptions_classifier(x):
    if x>30:
        return 10
    if x>20:
        return 15
    if x>5:
        return 5
    if x>1:
        return 1
    return 0

def photos_classifier(x):
    if x>20:
        return 15
    if x>10:
        return 10
    if x>5:
        return 5
    if x>1:
        return 2
    return 0

def gifts_classifier(x):
    if x>10:
        return 10
    if x>1:
        return 5
    return 0

def last_visit_classifier(x):
    if x==0:
        return 20
    if x==1:
        return 15
    if x<5:
        return 5
    if x<10:
        return 1
    return 0

def followers_classifier(x):
    if x>20000:
        return 50
    if x>2000:
        return 30
    if x>1000:
        return 25
    if x>500:
        return 20
    if x>200:
        return 15
    if x>100:
        return 10
    if x>30:
        return 5
    if x>1:
        return 1
    return 0

def followings_classifier(x):
    return followers_classifier(x)

def avg_views_classifier(x):
    return followers_classifier(x)

def posts_classifier(x):
    if x>50:
        return 40
    if x>30:
        return 30
    if x>10:
        return 20
    if x>5: 
        return 10
    if x>0:
        return 5
    return 0

def avg_likes_classifier(x):
    if x>100:
        return 30
    if x>500:
        return 25
    if x>200:
        return 20
    if x>100:
        return 15
    if x>50:
        return 10
    if x>5:
        return 5
    if x>0:
        return 1
    return 0

def avg_comments_classifier(x):
    if x>100:
        return 30
    if x>50:
        return 20
    if x>20:
        return 15
    if x>5:
        return 10
    if x>0:
        return 5
    return 0

# %%
for i in df.columns:
    df[i].fillna(df[i].median())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     126                 else:
# --> 127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmedian(values, axis, skipna, mask)
#     526     if not is_float_dtype(values):
# --> 527         values = values.astype('f8')
#     528         values[mask] = np.nan
#
# ValueError: could not convert string to float: 'yes'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     129                 try:
# --> 130                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     131                 except ValueError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmedian(values, axis, skipna, mask)
#     526     if not is_float_dtype(values):
# --> 527         values = values.astype('f8')
#     528         values[mask] = np.nan
#
# ValueError: could not convert string to float: 'yes'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-ee98d8bb08b9> in <module>
#       1 for i in df.columns:
#       2     if i!='user_id' and i!='sex':
# ----> 3         df[i].fillna(df[i].median())
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   10954                                       skipna=skipna)
#   10955         return self._reduce(f, name, axis=axis, skipna=skipna,
# > 10956                             numeric_only=numeric_only)
#   10957
#   10958     return set_function_name(stat_func, name, cls)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3628                                           'numeric_only.'.format(name))
#    3629             with np.errstate(all='ignore'):
# -> 3630                 return op(delegate, skipna=skipna, **kwds)
#    3631
#    3632         # TODO(EA) dispatch to Index
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      74             try:
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
#      78                 # we want to transform an object array
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     136
#     137                     if is_object_dtype(values):
# --> 138                         raise TypeError(e)
#     139                     raise
#     140
#
# TypeError: could not convert string to float: 'yes'
